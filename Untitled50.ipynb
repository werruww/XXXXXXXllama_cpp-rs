# %%
# !git clone https://github.com/ShelbyJenkins/llm_client.git
# Out:
# Cloning into 'llm_client'...
# remote: Enumerating objects: 2212, done.
# remote: Counting objects: 100% (372/372), done.
# remote: Compressing objects: 100% (299/299), done.
# remote: Total 2212 (delta 83), reused 266 (delta 67), pack-reused 1840 (from 1)
# Receiving objects: 100% (2212/2212), 10.11 MiB | 9.66 MiB/s, done.
# Resolving deltas: 100% (1007/1007), done.

# %%
# !curl --proto '=https' --tlsv1.2 -sSf https://sh.rustup.rs | sh -s -- -y

import os
os.environ['PATH'] += ":/root/.cargo/bin"

# !cargo --version
# Out:
# info: downloading installer
# info: profile set to 'default'
# info: default host triple is x86_64-unknown-linux-gnu
# info: syncing channel updates for 'stable-x86_64-unknown-linux-gnu'
# info: latest update on 2025-04-03, rust version 1.86.0 (05f9846f8 2025-03-31)
# info: downloading component 'cargo'
#   8.8 MiB /   8.8 MiB (100 %)   2.8 MiB/s in  2s
# info: downloading component 'clippy'
#   2.8 MiB /   2.8 MiB (100 %)   1.6 MiB/s in  1s
# info: downloading component 'rust-docs'
#  21.2 MiB /  21.2 MiB (100 %)   5.9 MiB/s in  2s
# info: downloading component 'rust-std'
#  27.1 MiB /  27.1 MiB (100 %)   5.5 MiB/s in  3s
# info: downloading component 'rustc'
#  72.8 MiB /  72.8 MiB (100 %)  11.9 MiB/s in  7s
# info: downloading component 'rustfmt'
# info: installing component 'cargo'
# info: installing component 'clippy'
# info: installing component 'rust-docs'
#  21.2 MiB /  21.2 MiB (100 %)   2.2 MiB/s in  8s
# info: installing component 'rust-std'
# ...

# %%
# %cd llm_client
# Out:
# /content/llm_client

# %%
# %cd /content/llm_client/llm_client
# !cargo run

# %%
# %cd /content/llm_client/llm_client/examples

# %%
cargo run --example basic_completion

# %%
cargo run --example basic_completion

# %%
# %cd /content/llm_client/llm_client/examples
# !cargo run --example basic_completion
# Out:
# /content/llm_client/llm_client/examples
# ...
# package:   /content/llm_client/llm_gui/Cargo.toml
# workspace: /content/llm_client/Cargo.toml
#     Updating crates.io index
#      Locking 520 packages to latest compatible versions
#       Adding objc2 v0.5.2 (available: v0.6.1)
#       Adding objc2-metal v0.2.2 (available: v0.3.1)
#       Adding secrecy v0.8.0 (available: v0.10.3)
#       Adding sysinfo v0.33.1 (available: v0.35.0)
#       Adding unicode-width v0.1.13 (available: v0.1.14)
# ...
#   Downloaded atomic-waker v1.1.2
#   Downloaded anstyle-query v1.1.2
#   Downloaded adler2 v2.0.0
#   Downloaded darling_macro v0.20.11
#   Downloaded anstyle v1.0.10
#   Downloaded http-body v1.0.1
#   Downloaded readability v0.3.0
#   Downloaded phf_generator v0.10.0
#   Downloaded want v0.3.1
#   Downloaded quote v1.0.40
#   Downloaded zstd-safe v7.2.4
#   Downloaded is_terminal_polyfill v1.70.1
#   Downloaded yoke v0.7.5
#   Downloaded lazy_static v1.5.0
#   Downloaded linkify v0.10.0
# ...

# %%
# !rustup install nightly
# Out:
# info: syncing channel updates for 'nightly-x86_64-unknown-linux-gnu'
# info: latest update on 2025-05-06, rust version 1.88.0-nightly (2e6882ac5 2025-05-05)
# info: downloading component 'cargo'
# info: downloading component 'clippy'
# info: downloading component 'rust-docs'
# info: downloading component 'rust-std'
# info: downloading component 'rustc'
# info: downloading component 'rustfmt'
# info: installing component 'cargo'
#   9.5 MiB /   9.5 MiB (100 %)   9.3 MiB/s in  1s
# info: installing component 'clippy'
# info: installing component 'rust-docs'
#  20.1 MiB /  20.1 MiB (100 %)   2.1 MiB/s in  7s
# info: installing component 'rust-std'
#  27.1 MiB /  27.1 MiB (100 %)   8.1 MiB/s in  3s
# info: installing component 'rustc'
#  76.1 MiB /  76.1 MiB (100 %)   6.7 MiB/s in 10s
# info: installing component 'rustfmt'
#
#   nightly-x86_64-unknown-linux-gnu installed - rustc 1.88.0-nightly (2e6882ac5 2025-05-05)
#
# info: checking for self-update

# %%
# !rustup default nightly
# Out:
# info: using existing install for 'nightly-x86_64-unknown-linux-gnu'
# info: default toolchain set to 'nightly-x86_64-unknown-linux-gnu'
#
#   nightly-x86_64-unknown-linux-gnu unchanged - rustc 1.88.0-nightly (2e6882ac5 2025-05-05)

# %%
# !cargo update
# Out:
# ...
# package:   /content/llm_client/llm_gui/Cargo.toml
# workspace: /content/llm_client/Cargo.toml
#     Updating crates.io index
#      Locking 0 packages to latest compatible versions
# note: pass `--verbose` to see 5 unchanged dependencies behind latest

# %%
# %cd /content/llm_client/llm_client/examples
# !cargo run --example basic_completion
# Out:
# /content/llm_client/llm_client/examples
# ...
# package:   /content/llm_client/llm_gui/Cargo.toml
# workspace: /content/llm_client/Cargo.toml
#    Compiling proc-macro2 v1.0.95
#    Compiling unicode-ident v1.0.18
#    Compiling libc v0.2.172
#    Compiling quote v1.0.40
#    Compiling syn v2.0.101
#    Compiling cfg-if v1.0.0
#    Compiling jobserver v0.1.33
#    Compiling shlex v1.3.0
#    Compiling cc v1.2.21
#    Compiling memchr v2.7.4
#    Compiling pkg-config v0.3.32
#    Compiling once_cell v1.21.3
#    Compiling log v0.4.27
#    Compiling autocfg v1.4.0
#    Compiling itoa v1.0.15
#    Compiling smallvec v1.15.0
#    Compiling pin-project-lite v0.2.16
#    Compiling getrandom v0.2.16
#    Compiling fnv v1.0.7
#    Compiling zerocopy v0.8.25
#    Compiling serde_derive v1.0.219
#    Compiling ppv-lite86 v0.2.21
#    Compiling rand_core v0.6.4
#    Compiling serde v1.0.219
#    Compiling rand_chacha v0.3.1
#    Compiling synstructure v0.13.2
#    Compiling tracing-core v0.1.33
# ...

# %%
rust
    // check if CUDA is available
    let has_cuda = std::process::Command::new("nvcc")
        .arg("--version")
        .output()
        .is_ok();

# %%
# %cd /content/llm_client/llm_interface
# !cargo build
# Out:
# /content/llm_client/llm_interface
# ...
# package:   /content/llm_client/llm_gui/Cargo.toml
# workspace: /content/llm_client/Cargo.toml
#    Compiling tokio v1.45.0
#    Compiling llm_interface v0.0.3 (/content/llm_client/llm_interface)
# ...
# error: failed to run custom build command for `llm_interface v0.0.3 (/content/llm_client/llm_interface)`
#
# Caused by:
#   process didn't exit successfully: `/content/llm_client/target/debug/build/llm_interface-ba5316b76fef7d54/build-script-build` (exit status: 1)
#   --- stdout
#   cargo:rerun-if-changed=build.rs
#   Starting /content/llm_client/target/llama_cpp.build Logger
#   2025-05-07T00:21:46.762919Z TRACE llm_devices::llm_binary::binary: No such file or directory (os error 2)
#   2025-05-07T00:21:46.763063Z TRACE llm_devices::llm_binary: Directory /content/llm_client/target/llama_cpp does not exist, skipping removal
#   2025-05-07T00:21:46.926967Z TRACE llm_devices::llm_binary::build: Cmake found: cmake version 3.31.6
#
# ...

# %%
# %cd /content/llm_client/llm_interface
# !cargo build
# Out:
# /content/llm_client/llm_interface
# ...
# package:   /content/llm_client/llm_gui/Cargo.toml
# workspace: /content/llm_client/Cargo.toml
#    Compiling tokio-util v0.7.15
#    Compiling tokio-native-tls v0.3.1
#    Compiling tower v0.5.2
#    Compiling h2 v0.4.10
#    Compiling backoff v0.4.0
#    Compiling llm_interface v0.0.3 (/content/llm_client/llm_interface)
#    Compiling hyper v1.6.0
#    Compiling hyper-util v0.1.11
# ...
# error: failed to run custom build command for `llm_interface v0.0.3 (/content/llm_client/llm_interface)`
#
# Caused by:
#   process didn't exit successfully: `/content/llm_client/target/debug/build/llm_interface-ba5316b76fef7d54/build-script-build` (exit status: 1)
#   --- stdout
#   cargo:rerun-if-changed=build.rs
#   Starting /content/llm_client/target/llama_cpp.build Logger
#   2025-05-07T00:24:37.068741Z TRACE llm_devices::llm_binary::binary: No such file or directory (os error 2)
# ...

# %%
# !sudo apt update
# !sudo apt install -y cmake clang build-essential git curl libstdc++-12-dev
# Out:
# Hit:1 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Hit:3 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:4 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:5 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:6 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:7 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Hit:8 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:9 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Get:10 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [2,715 kB]
# Get:11 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [3,208 kB]
# Hit:12 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# ...

# %%
[features]
default = ["llama_cpp_backend"]
llama_cpp_backend = []

# %%
# !export CMAKE_BUILD_PARALLEL_LEVEL=2

# %%
# %cd /content/llm_client
# !cargo build --release
# Out:
# /content/llm_client
# error: failed to parse manifest at `/content/llm_client/Cargo.toml`
#
# Caused by:
#   this virtual manifest specifies a `features` section, which is not allowed

# %%
# !cargo build --release --features llama_cpp_backend
# Out:
# error: failed to parse manifest at `/content/llm_client/Cargo.toml`
#
# Caused by:
#   this virtual manifest specifies a `features` section, which is not allowed

# %%
# !cargo run --release --bin run_model --features llama_cpp_backend
# Out:
# error: failed to parse manifest at `/content/llm_client/Cargo.toml`
#
# Caused by:
#   this virtual manifest specifies a `features` section, which is not allowed

# %%
[features]
default = ["llama_cpp_backend"]
llama_cpp_backend = []

# %%
# !cargo run --release --bin run_model --features llama_cpp_backend
# Out:
# ...
# package:   /content/llm_client/llm_gui/Cargo.toml
# workspace: /content/llm_client/Cargo.toml
# error: no bin target named `run_model` in default-run packages
# help: available bin targets:
#     generate_models
#     llm_gui
#     server_runner

# %%
# %cd /content/llm_client
# !cargo build --release
# Out:
# /content/llm_client
# ...
# package:   /content/llm_client/llm_gui/Cargo.toml
# workspace: /content/llm_client/Cargo.toml
#    Compiling proc-macro2 v1.0.95
#    Compiling unicode-ident v1.0.18
#    Compiling libc v0.2.172
#    Compiling quote v1.0.40
#    Compiling cfg-if v1.0.0
#    Compiling syn v2.0.101
#    Compiling jobserver v0.1.33
#    Compiling shlex v1.3.0
#    Compiling cc v1.2.21
#    Compiling once_cell v1.21.3
#    Compiling memchr v2.7.4
#    Compiling autocfg v1.4.0
#    Compiling pkg-config v0.3.32
#    Compiling version_check v0.9.5
#    Compiling serde_derive v1.0.219
#    Compiling serde v1.0.219
#    Compiling smallvec v1.15.0
#    Compiling pin-project-lite v0.2.16
#    Compiling zerocopy v0.8.25
#    Compiling tracing-attributes v0.1.28
#    Compiling itoa v1.0.15
#    Compiling futures-core v0.3.31
#    Compiling log v0.4.27
#    Compiling tracing-core v0.1.33
#    Compiling futures-sink v0.3.31
#    Compiling slab v0.4.9
#    Compiling typenum v1.18.0
# ...

# %%
(base) alphaduriendur@hc-desktop-1:~/llama-cpp-rust-test$ cargo add llama_cpp --features cuda
    Updating crates.io index
